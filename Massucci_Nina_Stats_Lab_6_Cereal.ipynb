# %% [markdown]
# <a href="https://colab.research.google.com/github/ninamassucci/Data_sci/blob/main/Massucci_Nina_Stats_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f8c4ac93b20>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %%
plt.plot(x,y,'.');

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
loss
# Out:
# 3832.900751488163

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 413620.6718229087 -10.0 -10.0
# 395565.15718612267 -10.0 -7.777777777777778
# 378003.4697098306 -10.0 -5.555555555555555
# 360935.6093940323 -10.0 -3.333333333333333
# 344361.57623872784 -10.0 -1.1111111111111107
# 328281.3702439171 -10.0 1.1111111111111107
# 312694.99140960036 -10.0 3.333333333333334
# 297602.43973577727 -10.0 5.555555555555557
# 283003.71522244817 -10.0 7.777777777777779
# 268898.81786961283 -10.0 10.0
# 305821.4315228511 -7.777777777777778 -10.0
# 290235.05268853426 -7.777777777777778 -7.777777777777778
# 275142.5010147113 -7.777777777777778 -5.555555555555555
# 260543.77650138212 -7.777777777777778 -3.333333333333333
# 246438.87914854678 -7.777777777777778 -1.1111111111111107
# 232827.8089562053 -7.777777777777778 1.1111111111111107
# 219710.56592435756 -7.777777777777778 3.333333333333334
# 207087.15005300372 -7.777777777777778 5.555555555555557
# 194957.56134214372 -7.777777777777778 7.777777777777779
# 183321.7997917775 -7.777777777777778 10.0
# 214651.06499452447 -5.555555555555555 -10.0
# 201533.82196267677 -5.555555555555555 -7.777777777777778
# 188910.4060913229 -5.555555555555555 -5.555555555555555
# 176780.81738046286 -5.555555555555555 -3.333333333333333
# 165145.05583009668 -5.555555555555555 -1.1111111111111107
# 154003.12144022432 -5.555555555555555 1.1111111111111107
# 143355.01421084575 -5.555555555555555 3.333333333333334
# 133200.734141961 -5.555555555555555 5.555555555555557
# 123540.28123357012 -5.555555555555555 7.777777777777779
# 114373.65548567307 -5.555555555555555 10.0
# 140109.5722379287 -3.333333333333333 -10.0
# 129461.46500855018 -3.333333333333333 -7.777777777777778
# 119307.18493966544 -3.333333333333333 -5.555555555555555
# 109646.73203127454 -3.333333333333333 -3.333333333333333
# 100480.10628337748 -3.333333333333333 -1.1111111111111107
# 91807.30769597423 -3.333333333333333 1.1111111111111107
# 83628.33626906482 -3.333333333333333 3.333333333333334
# 75943.19200264923 -3.333333333333333 5.555555555555557
# 68751.87489672747 -3.333333333333333 7.777777777777779
# 62054.38495129956 -3.333333333333333 10.0
# 82196.9532530639 -1.1111111111111107 -10.0
# 74017.98182615449 -1.1111111111111107 -7.777777777777778
# 66332.83755973888 -1.1111111111111107 -5.555555555555555
# 59141.520453817124 -1.1111111111111107 -3.333333333333333
# 52444.0305083892 -1.1111111111111107 -1.1111111111111107
# 46240.3677234551 -1.1111111111111107 1.1111111111111107
# 40530.532099014825 -1.1111111111111107 3.333333333333334
# 35314.52363506838 -1.1111111111111107 5.555555555555557
# 30592.342331615753 -1.1111111111111107 7.777777777777779
# 26363.988188656956 -1.1111111111111107 10.0
# 40913.208039929996 1.1111111111111107 -10.0
# 35203.37241548972 1.1111111111111107 -7.777777777777778
# 29987.363951543273 1.1111111111111107 -5.555555555555555
# 25265.182648090646 1.1111111111111107 -3.333333333333333
# 21036.82850513186 1.1111111111111107 -1.1111111111111107
# 17302.301522666887 1.1111111111111107 1.1111111111111107
# 14061.601700695746 1.1111111111111107 3.333333333333334
# 11314.729039218433 1.1111111111111107 5.555555555555557
# 9061.683538234947 1.1111111111111107 7.777777777777779
# 7302.465197745288 1.1111111111111107 10.0
# 16258.336598527003 3.333333333333334 -10.0
# 13017.636776555863 3.333333333333334 -7.777777777777778
# 10270.764115078553 3.333333333333334 -5.555555555555555
# 8017.718614095065 3.333333333333334 -3.333333333333333
# 6258.5002736054075 3.333333333333334 -1.1111111111111107
# 4993.109093609576 3.333333333333334 1.1111111111111107
# 4221.545074107572 3.333333333333334 3.333333333333334
# 3943.808215099395 3.333333333333334 5.555555555555557
# 4159.898516585046 3.333333333333334 7.777777777777779
# 4869.815978564523 3.333333333333334 10.0
# 8232.338928854937 5.555555555555557 -10.0
# 7460.774909352935 5.555555555555557 -7.777777777777778
# 7183.038050344758 5.555555555555557 -5.555555555555555
# 7399.128351830409 5.555555555555557 -3.333333333333333
# 8109.045813809889 5.555555555555557 -1.1111111111111107
# 9312.790436283194 5.555555555555557 1.1111111111111107
# 11010.36221925033 5.555555555555557 3.333333333333334
# 13201.761162711291 5.555555555555557 5.555555555555557
# 15886.98726666608 5.555555555555557 7.777777777777779
# 19066.04053111469 5.555555555555557 10.0
# 16835.215030913787 7.777777777777779 -10.0
# 18532.78681388092 7.777777777777779 -7.777777777777778
# 20724.185757341875 7.777777777777779 -5.555555555555555
# 23409.411861296667 7.777777777777779 -3.333333333333333
# 26588.465125745275 7.777777777777779 -1.1111111111111107
# 30261.345550687725 7.777777777777779 1.1111111111111107
# 34428.05313612399 7.777777777777779 3.333333333333334
# 39088.58788205408 7.777777777777779 5.555555555555557
# 44242.94978847801 7.777777777777779 7.777777777777779
# 49891.13885539576 7.777777777777779 10.0
# 42066.96490470354 10.0 -10.0
# 46233.67249013982 10.0 -7.777777777777778
# 50894.2072360699 10.0 -5.555555555555555
# 56048.56914249383 10.0 -3.333333333333333
# 61696.758209411564 10.0 -1.1111111111111107
# 67838.77443682317 10.0 1.1111111111111107
# 74474.61782472856 10.0 3.333333333333334
# 81604.28837312778 10.0 5.555555555555557
# 89227.78608202083 10.0 7.777777777777779
# 97345.11095140771 10.0 10.0

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
